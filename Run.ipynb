# %% [markdown]
# # 计算基态的波函数

# %%
include("Main_module.jl")
using .TDSE

# %%
P = Parameter()
Wave = wave_function();

# %%
ITR!(P, Wave)
# Out:
# The Energy is -0.6697753802587859
# 迭代次数:264,虚时间0.0 + 13.200000000000001im

# %%
using PyPlot
xlim(-10,10)
plot_Ground()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall C:\Users\86187\.julia\packages\PyCall\BD546\src\numpy.jl:67
# PyObject Text(24.000000000000007, 0.5, 'amplitude')

# %%
include("Calculation_HHG.jl")
# Out:
# Main.HHG

# %%
include("Main_module.jl")
using .TDSE
P = Parameter()
plot_probability(P)
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall C:\Users\86187\.julia\packages\PyCall\BD546\src\numpy.jl:67
# PyObject Text(0.5, 24.0, 'X(a.u)')

# %%
using CSV, DataFrames

# %%
df = DataFrame(A::Vector{Int64}=[1,2,3],B::Vector{Complex{Float64}}=[1im,2im,3im])
# Out:
# syntax: invalid keyword argument name "A::Vector{Int64}" around In[3]:1
#
# Stacktrace:
#  [1] top-level scope
#    @ In[3]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094

# %%
module test
include("Main_module.jl")
using .TDSE
plot_HHG()
end
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# sys:1: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# Main.test
